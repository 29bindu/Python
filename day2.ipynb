# %%
info=("hima",22,"student")
print(info[0])
print(info[-2])
print(len(info))
print(info*2)
print(info+('33','44'))
# Out:
# hima
# 22
# 3
# ('hima', 22, 'student', 'hima', 22, 'student')
# ('hima', 22, 'student', '33', '44')

# %%
nest=((1,2),('a','b'),(5,6))
print(nest[1][0])
# Out:
# a

# %%
person={"name":"bindu","age":32,"city":"vijayawada"}
print(person)
print("accessing and modifying the person age:")
person["age"]=31
print(person)
# Out:
# {'name': 'bindu', 'age': 32, 'city': 'vijayawada'}
# accessing and modifying the person age:
# {'name': 'bindu', 'age': 31, 'city': 'vijayawada'}

# %%
person={"name":"bindu","age":32,"city":"vijayawada"}
print(person)
person["age"]=31
print(person)
person['email']='hiima29@gmail.com'
print(person)
# Out:
# {'name': 'bindu', 'age': 32, 'city': 'vijayawada'}
# {'name': 'bindu', 'age': 31, 'city': 'vijayawada'}
# {'name': 'bindu', 'age': 31, 'city': 'vijayawada', 'email': 'hiima29@gmail.com'}

# %%
person={"name":"bindu","age":32,"city":"vijayawada"}
print(person)
person["age"]=31
print(person)
person['email']='hiima29@gmail.com'
print(person)
del person['city']
print(person)
# Out:
# {'name': 'bindu', 'age': 32, 'city': 'vijayawada'}
# {'name': 'bindu', 'age': 31, 'city': 'vijayawada'}
# {'name': 'bindu', 'age': 31, 'city': 'vijayawada', 'email': 'hiima29@gmail.com'}
# {'name': 'bindu', 'age': 31, 'email': 'hiima29@gmail.com'}

# %%
person={"name":"bindu","age":32,"city":"vijayawada"}
print(person)
person["age"]=31
print(person)
person['email']='hiima29@gmail.com'
print(person)
del person['city']
print(person)
print("All keys & values")
print(person.keys())
print(person.values())
print(person.items())
print(person.get("age"))
# Out:
# {'name': 'bindu', 'age': 32, 'city': 'vijayawada'}
# {'name': 'bindu', 'age': 31, 'city': 'vijayawada'}
# {'name': 'bindu', 'age': 31, 'city': 'vijayawada', 'email': 'hiima29@gmail.com'}
# {'name': 'bindu', 'age': 31, 'email': 'hiima29@gmail.com'}
# All keys & values
# dict_keys(['name', 'age', 'email'])
# dict_values(['bindu', 31, 'hiima29@gmail.com'])
# dict_items([('name', 'bindu'), ('age', 31), ('email', 'hiima29@gmail.com')])
# 31

# %%
info={
    'vijay':{"salary":120000,"perks":30000},

    'mark':{"salary":180000,"perks":50000},
     }
print(info["mark"]["perks"])
# Out:
# 50000

# %%
location={(40.4588,-76.757):"New York",(34.3466,-119.6545):"Melbourne"}
print(location[(40.4588,-76.757)])
# Out:
# New York
